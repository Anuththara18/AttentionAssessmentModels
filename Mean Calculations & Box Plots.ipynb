# %%
# importing libraries    
import numpy as nm    
import matplotlib.pyplot as mtp    
import pandas as pd   
from sklearn.cluster import DBSCAN
from numpy import unique
from numpy import where
from matplotlib import pyplot

# %%
dataset = pd.read_csv('data.csv')  
print(dataset['id'].count())

print("---------------------")

dataset0 = dataset[dataset.game == 'Focused']
print(dataset0['id'].count())

dataset1 = dataset[dataset.game == 'Selective']
print(dataset1['id'].count())

dataset2 = dataset[dataset.game == 'Sustained']
print(dataset2['id'].count())

dataset3 = dataset[dataset.game == 'Divided']
print(dataset3['id'].count())

dataset4 = dataset[dataset.game == 'Alternating']
print(dataset4['id'].count())

print("---------------------")

dataset5 = dataset[dataset.child_age == 4]
print(dataset5['id'].count())

dataset6 = dataset[dataset.child_age == 5]
print(dataset6['id'].count())

dataset7 = dataset[dataset.child_age == 6]
print(dataset7['id'].count())

dataset8 = dataset[dataset.child_age == 7]
print(dataset8['id'].count())

print("---------------------")

#dataset9 = dataset[[dataset.child_age == 4] && [dataset.game == 'Alternating']]
#print(dataset9['id'].count())
# Out:
# 363
# ---------------------
# 81
# 164
# 39
# 40
# 39
# ---------------------
# 111
# 109
# 70
# 73
# ---------------------

# %%
# importing libraries
import matplotlib.pyplot as plt
import seaborn

# Libraries
import matplotlib.pyplot as plt

plt.figure(figsize=(8,10))

# declaring data
data = [81, 164, 39, 40, 39]
keys = ['Focused', 'Selective', 'Sustained', 'Divided', 'Alternating']

# define Seaborn color palette to use
palette_color = seaborn.color_palette('bright')

# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%')

# displaying chart
plt.show()


plt.figure(figsize=(8,10))

# declaring data
data = [111, 109, 70, 73]
keys = ['Age 4', 'Age 5', 'Age 6', 'Age 7']

# define Seaborn color palette to use
palette_color = seaborn.color_palette('bright')

# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%', textprops = {"fontsize":25})

# displaying chart
plt.show()

######################################################################
 
plt.figure(figsize=(8,10))

# Make data: I have 3 groups and 7 subgroups
group_names=['Focused Attention', 'Selective Attention', 'Sustained Attention', 'Divided Attention', 'Alternating Attention']
group_size=[81, 164, 39, 40, 39]
subgroup_names=['A4', 'A5', 'A6', 'A7', 'A4', 'A5', 'A6', 'A7', 'A4', 'A5', 'A6', 'A7', 'A4', 'A5', 'A6', 'A7', 'A4', 'A5', 'A6', 'A7']
subgroup_size=[26, 26, 14, 15, 55, 54, 26, 29, 8, 9, 11, 11, 11, 9, 10, 10, 11, 11, 9, 8]
 

# Create colors
a, b, c, d, e=[plt.cm.Blues, plt.cm.Reds, plt.cm.Greens, plt.cm.Purples, plt.cm.Oranges]
 
# First Ring (outside)
fig, ax = plt.subplots()
ax.axis('equal')
mypie, _ = ax.pie(group_size, radius=2.3, labels=group_names, colors=[a(0.6), b(0.6), c(0.6), d(0.6), e(0.6)] )
plt.setp( mypie, width=0.3, edgecolor='white')
 
# Second Ring (Inside)
mypie2, _ = ax.pie(subgroup_size, radius=2, labels=subgroup_names, labeldistance=0.7, 
                   colors=[a(0.5), a(0.4), a(0.3), a(0.2), 
                          b(0.5), b(0.4), b(0.3), b(0.2),
                          c(0.5), c(0.4), c(0.3), c(0.2),
                          d(0.5), d(0.4), d(0.3), d(0.2),
                          e(0.5), e(0.4), e(0.3), e(0.2)])

plt.setp( mypie2, width=0.9, edgecolor='white')
plt.margins(0,0)
 
# show it
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load the dataset
df = pd.read_csv("data.csv") 
plot = sns.boxplot(x =df['game'], y=df["percentage_no_of_correct_responses"] );
plot.set(xlabel ="Attention Type", ylabel = "% No. of correct responses")
plt.show()

df = pd.read_csv("data.csv") 
df.drop(df.index[df['game'] == 'Focused'], inplace = True)
df.drop(df.index[df['game'] == 'Sustained'], inplace = True)
plot = sns.boxplot(x =df['game'], y=df["cer"] );
plot.set(xlabel ="Attention Type", ylabel = "% No. of commission errors")
plt.show()

df = pd.read_csv("data.csv") 
plot = sns.boxplot(x =df['game'], y=df["oer"] );
plot.set(xlabel ="Attention Type", ylabel = "% No. of omission errors")
plt.show()

df = pd.read_csv("data.csv") 
df.drop(df.index[df['game'] == 'Selective'], inplace = True)
plot = sns.boxplot(x =df['game'], y=df["mean_reaction_time"] );
plot.set(xlabel ="Attention Type", ylabel = "Mean reaction time")
plt.show()

df = pd.read_csv("data.csv") 
df.drop(df.index[df['game'] == 'Focused'], inplace = True)
df.drop(df.index[df['game'] == 'Alternating'], inplace = True)
df.drop(df.index[df['game'] == 'Divided'], inplace = True)
plot = sns.boxplot(x =df['game'], y=df["total_duration"] );
plot.set(xlabel ="Attention Type", ylabel = "Total duration")
plt.show()

# %% [markdown]
# # Focused Attention

# %%
# Importing the dataset  
dataset = pd.read_csv('data.csv')  

dataset.drop(dataset.index[dataset['game'] == 'Alternating'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Divided'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Sustained'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Selective'], inplace = True)
display(dataset)

print(dataset['id'].count())

dataset5 = dataset[dataset.child_age == 4]
print(dataset5['id'].count())

dataset6 = dataset[dataset.child_age == 5]
print(dataset6['id'].count())

dataset7 = dataset[dataset.child_age == 6]
print(dataset7['id'].count())

dataset8 = dataset[dataset.child_age == 7]
print(dataset8['id'].count())
# Out:
#       id  child_gender  child_age  total_correct_responses  correct_responses  \
# 79    80             1          4                       10                 10
# 80    81             1          4                       10                 10
# 81    82             1          4                       10                 10
# 82    83             2          4                       10                 10
# 83    84             2          4                       10                  9
# ..   ...           ...        ...                      ...                ...
# 155  156             1          7                       12                 12
# 156  157             1          7                       12                 12
# 157  158             1          7                       12                 12
# 158  159             1          7                       12                 12
# 159  160             1          7                       12                 12
#
# ...

# %%
# ALL
print(dataset['percentage_no_of_correct_responses'].mean())
print(dataset['oer'].mean())
print(dataset['mean_reaction_time'].mean())
# Out:
# 96.02880658444445
# 3.9711934158148146
# 1291.7530864197531

# %%
# Age 4
dataset1 = dataset[dataset.child_age == 4]
#display(dataset)
print(dataset1['percentage_no_of_correct_responses'].mean())
print(dataset1['oer'].mean())
print(dataset1['mean_reaction_time'].mean())
# Out:
# 93.07692307692308
# 6.923076923076923
# 1416.3461538461538

# %%
# Age 5
dataset2 = dataset[dataset.child_age == 5]
print(dataset2['percentage_no_of_correct_responses'].mean())
print(dataset2['oer'].mean())
print(dataset2['mean_reaction_time'].mean())
# Out:
# 96.15384615384617
# 3.8461538466153846
# 1432.3846153846155

# %%
# Age 6
dataset3 = dataset[dataset.child_age == 6]
print(dataset3['percentage_no_of_correct_responses'].mean())
print(dataset3['oer'].mean())
print(dataset3['mean_reaction_time'].mean())
# Out:
# 98.80952381
# 1.1904761904285714
# 1003.1428571428571

# %%
# Age 7
dataset4 = dataset[dataset.child_age == 7]
print(dataset4['percentage_no_of_correct_responses'].mean())
print(dataset4['oer'].mean())
print(dataset4['mean_reaction_time'].mean())
# Out:
# 98.33333333333333
# 1.666666666866667
# 1101.4

# %% [markdown]
# # Selective Attention

# %%
# Importing the dataset  
dataset = pd.read_csv('data.csv')  

dataset.drop(dataset.index[dataset['game'] == 'Alternating'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Divided'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Sustained'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Focused'], inplace = True)
display(dataset)

print(dataset['id'].count())

dataset5 = dataset[dataset.child_age == 4]
print(dataset5['id'].count())

dataset6 = dataset[dataset.child_age == 5]
print(dataset6['id'].count())

dataset7 = dataset[dataset.child_age == 6]
print(dataset7['id'].count())

dataset8 = dataset[dataset.child_age == 7]
print(dataset8['id'].count())
# Out:
#       id  child_gender  child_age  total_correct_responses  correct_responses  \
# 160  161             1          4                        8                  8
# 161  162             2          4                        6                  6
# 162  163             2          4                        6                  6
# 163  164             2          4                        6                  6
# 164  165             2          4                        7                  6
# ..   ...           ...        ...                      ...                ...
# 319  320             1          7                        8                  8
# 320  321             1          7                        6                  0
# 321  322             1          7                        7                  5
# 322  323             1          7                        7                  7
# 323  324             1          7                        6                  6
#
# ...

# %%
# ALL
print(dataset['percentage_no_of_correct_responses'].mean())
print(dataset['oer'].mean())
print(dataset['cer'].mean())
print(dataset['total_duration'].mean())
# Out:
# 93.31083042957317
# 6.689169570426829
# 4.03721447945122
# 12678.55487804878

# %%
# Age 4
dataset1 = dataset[dataset.child_age == 4]
#display(dataset)
print(dataset1['percentage_no_of_correct_responses'].mean())
print(dataset1['oer'].mean())
print(dataset1['cer'].mean())
print(dataset1['total_duration'].mean())
# Out:
# 93.46320346290909
# 6.536796537090909
# 4.354256854363636
# 12729.127272727274

# %%
# Age 5
dataset2 = dataset[dataset.child_age == 5]
print(dataset2['percentage_no_of_correct_responses'].mean())
print(dataset2['oer'].mean())
print(dataset2['cer'].mean())
print(dataset2['total_duration'].mean())
# Out:
# 95.50264550240742
# 4.4973544975925925
# 3.802910053333334
# 13206.277777777777

# %%
# Age 6
dataset3 = dataset[dataset.child_age == 6]
print(dataset3['percentage_no_of_correct_responses'].mean())
print(dataset3['oer'].mean())
print(dataset3['cer'].mean())
print(dataset3['total_duration'].mean())
# Out:
# 91.34615384653846
# 8.653846153461538
# 2.9532967034615387
# 11795.0

# %%
# Age 7
dataset4 = dataset[dataset.child_age == 7]
print(dataset4['percentage_no_of_correct_responses'].mean())
print(dataset4['oer'].mean())
print(dataset4['cer'].mean())
print(dataset4['total_duration'].mean())
# Out:
# 90.70197044310345
# 9.298029556896552
# 4.844006567931035
# 12392.137931034482

# %% [markdown]
# # Sustained Attention

# %%
# Importing the dataset  
dataset = pd.read_csv('data.csv')  

dataset.drop(dataset.index[dataset['game'] == 'Alternating'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Divided'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Focused'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Selective'], inplace = True)
display(dataset)

print(dataset['id'].count())

dataset5 = dataset[dataset.child_age == 4]
print(dataset5['id'].count())

dataset6 = dataset[dataset.child_age == 5]
print(dataset6['id'].count())

dataset7 = dataset[dataset.child_age == 6]
print(dataset7['id'].count())

dataset8 = dataset[dataset.child_age == 7]
print(dataset8['id'].count())
# Out:
#       id  child_gender  child_age  total_correct_responses  correct_responses  \
# 324  325             2          4                       20                 16
# 325  326             1          4                       20                 18
# 326  327             2          4                       31                 28
# 327  328             2          4                       13                 12
# 328  329             2          4                        7                  7
# 329  330             1          4                       17                 15
# 330  331             1          4                       15                 13
# 331  332             1          4                        4                  3
# 332  333             2          5                       34                 33
# 333  334             2          5                        7                  5
# 334  335             1          5                       14                 13
# ...

# %%
# ALL
print(dataset['percentage_no_of_correct_responses'].mean())
print(dataset['oer'].mean())
print(dataset['mean_reaction_time'].mean())
print(dataset['total_duration'].mean())
# Out:
# 87.32436793128204
# 15.239734633256411
# 1123.7692307692307
# 72451.38461538461

# %%
# Age 4
dataset1 = dataset[dataset.child_age == 4]
#display(dataset)
print(dataset1['percentage_no_of_correct_responses'].mean())
print(dataset1['oer'].mean())
print(dataset1['mean_reaction_time'].mean())
print(dataset1['total_duration'].mean())
# Out:
# 87.81652921874999
# 12.183470782125
# 1410.625
# 104740.25

# %%
# Age 5
dataset2 = dataset[dataset.child_age == 5]
print(dataset2['percentage_no_of_correct_responses'].mean())
print(dataset2['oer'].mean())
print(dataset2['mean_reaction_time'].mean())
print(dataset2['total_duration'].mean())
# Out:
# 84.91057961777778
# 26.200531493777778
# 1105.7777777777778
# 73384.77777777778

# %%
# Age 6
dataset3 = dataset[dataset.child_age == 6]
print(dataset3['percentage_no_of_correct_responses'].mean())
print(dataset3['oer'].mean())
print(dataset3['mean_reaction_time'].mean())
print(dataset3['total_duration'].mean())
# Out:
# 87.91814246454545
# 12.081857535818182
# 987.9090909090909
# 43969.181818181816

# %%
# Age 7
dataset4 = dataset[dataset.child_age == 7]
print(dataset4['percentage_no_of_correct_responses'].mean())
print(dataset4['oer'].mean())
print(dataset4['mean_reaction_time'].mean())
print(dataset4['total_duration'].mean())
# Out:
# 88.34757562727272
# 11.652424372909092
# 1065.7272727272727
# 76687.09090909091

# %% [markdown]
# # Divided Attention

# %%
# Importing the dataset  
dataset = pd.read_csv('data.csv')  

dataset.drop(dataset.index[dataset['game'] == 'Alternating'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Focused'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Sustained'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Selective'], inplace = True)
display(dataset)

print(dataset['id'].count())

dataset5 = dataset[dataset.child_age == 4]
print(dataset5['id'].count())

dataset6 = dataset[dataset.child_age == 5]
print(dataset6['id'].count())

dataset7 = dataset[dataset.child_age == 6]
print(dataset7['id'].count())

dataset8 = dataset[dataset.child_age == 7]
print(dataset8['id'].count())
# Out:
#     id  child_gender  child_age  total_correct_responses  correct_responses  \
# 39  40             2          4                        8                  5
# 40  41             1          4                        8                  5
# 41  42             2          4                        8                  7
# 42  43             2          4                        8                  4
# 43  44             1          4                        8                  6
# 44  45             1          4                        8                  8
# 45  46             1          4                        8                  7
# 46  47             1          4                        8                  8
# 47  48             1          4                        8                  8
# 48  49             1          4                        8                  7
# 49  50             1          4                        8                  5
# ...

# %%
# ALL
print(dataset['percentage_no_of_correct_responses'].mean())
print(dataset['oer'].mean())
print(dataset['cer'].mean())
print(dataset['mean_reaction_time'].mean())
# Out:
# 82.5
# 17.5
# 27.1875
# 1009.425

# %%
# Age 4
dataset1 = dataset[dataset.child_age == 4]
#display(dataset)
print(dataset1['percentage_no_of_correct_responses'].mean())
print(dataset1['oer'].mean())
print(dataset1['cer'].mean())
print(dataset1['mean_reaction_time'].mean())
# Out:
# 79.54545454545455
# 20.454545454545453
# 34.09090909090909
# 1203.3636363636363

# %%
# Age 5
dataset2 = dataset[dataset.child_age == 5]
print(dataset2['percentage_no_of_correct_responses'].mean())
print(dataset2['oer'].mean())
print(dataset2['cer'].mean())
print(dataset2['mean_reaction_time'].mean())
# Out:
# 75.0
# 25.0
# 30.555555555555557
# 1130.6666666666667

# %%
# Age 6
dataset3 = dataset[dataset.child_age == 6]
print(dataset3['percentage_no_of_correct_responses'].mean())
print(dataset3['oer'].mean())
print(dataset3['cer'].mean())
print(dataset3['mean_reaction_time'].mean())
# Out:
# 87.5
# 12.5
# 28.75
# 873.4

# %%
# Age 7
dataset4 = dataset[dataset.child_age == 7]
print(dataset4['percentage_no_of_correct_responses'].mean())
print(dataset4['oer'].mean())
print(dataset4['cer'].mean())
print(dataset4['mean_reaction_time'].mean())
# Out:
# 87.5
# 12.5
# 15.0
# 823.0

# %% [markdown]
# # Alternating Attention

# %%
# Importing the dataset  
dataset = pd.read_csv('data.csv')  

dataset.drop(dataset.index[dataset['game'] == 'Focused'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Divided'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Sustained'], inplace = True)
dataset.drop(dataset.index[dataset['game'] == 'Selective'], inplace = True)
display(dataset)

print(dataset['id'].count())

dataset5 = dataset[dataset.child_age == 4]
print(dataset5['id'].count())

dataset6 = dataset[dataset.child_age == 5]
print(dataset6['id'].count())

dataset7 = dataset[dataset.child_age == 6]
print(dataset7['id'].count())

dataset8 = dataset[dataset.child_age == 7]
print(dataset8['id'].count())
# Out:
#     id  child_gender  child_age  total_correct_responses  correct_responses  \
# 0    1             2          4                       19                 18
# 1    2             1          4                       19                 19
# 2    3             2          4                       19                 18
# 3    4             2          4                       19                 19
# 4    5             2          4                       19                 19
# 5    6             1          4                       19                 15
# 6    7             1          4                       19                 19
# 7    8             1          4                       19                 15
# 8    9             1          4                       19                 18
# 9   10             1          4                       19                 13
# 10  11             2          4                       19                 19
# ...

# %%
# ALL
print(dataset['percentage_no_of_correct_responses'].mean())
print(dataset['oer'].mean())
print(dataset['cer'].mean())
print(dataset['mean_reaction_time'].mean())
# Out:
# 94.46693657358976
# 5.533063427948719
# 19.16329284679487
# 1174.4615384615386

# %%
# Age 4
dataset1 = dataset[dataset.child_age == 4]
#display(dataset)
print(dataset1['percentage_no_of_correct_responses'].mean())
print(dataset1['oer'].mean())
print(dataset1['cer'].mean())
print(dataset1['mean_reaction_time'].mean())
# Out:
# 91.8660287090909
# 8.133971292272726
# 11.004784688181816
# 1409.7272727272727

# %%
# Age 5
dataset2 = dataset[dataset.child_age == 5]
print(dataset2['percentage_no_of_correct_responses'].mean())
print(dataset2['oer'].mean())
print(dataset2['cer'].mean())
print(dataset2['mean_reaction_time'].mean())
# Out:
# 93.30143540818182
# 6.698564593181818
# 17.70334928181818
# 1236.909090909091

# %%
# Age 6
dataset3 = dataset[dataset.child_age == 6]
print(dataset3['percentage_no_of_correct_responses'].mean())
print(dataset3['oer'].mean())
print(dataset3['cer'].mean())
print(dataset3['mean_reaction_time'].mean())
# Out:
# 97.66081871555555
# 2.339181286666667
# 26.900584794444445
# 958.1111111111111

# %%
# Age 7
dataset4 = dataset[dataset.child_age == 7]
print(dataset4['percentage_no_of_correct_responses'].mean())
print(dataset4['oer'].mean())
print(dataset4['cer'].mean())
print(dataset4['mean_reaction_time'].mean())
# Out:
# 96.05263158
# 3.94736842125
# 23.684210525624998
# 1008.5
